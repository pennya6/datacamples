# %% [markdown]
# #### 1

# %%
from pandas import read_csv

# %%
dataset = read_csv('Connections_UK.csv',header=None)
dataset
# Out:
#             0                                1             2             3   \
# 0       Metric                 Market, Operator       Q1 2010       Q2 2010
# 1  Connections                 3 (CK Hutchison)    5,055,187     5,127,360
# 2  Connections                          EE (BT)   17,175,000    27,093,000
# 3  Connections                         Vodafone   19,954,383    19,965,191
# 4  Connections                  O2 (Telefónica)   21,355,500    21,605,600
# 5  Connections         Orange  (Merged Q2 2010)   16,442,000            NaN
# 6  Connections  Relish Broadband (UK Broadband)           NaN           NaN
# 7  Connections                   United Kingdom   79,982,070    73,791,151
#
#              4             5             6             7             8   \
# 0       Q3 2010       Q4 2010       Q1 2011       Q2 2011       Q3 2011
# 1    5,352,510     5,577,660     5,652,029     5,726,398     6,083,239
# 2   27,101,000    27,214,000    26,978,000    26,803,000    26,762,000
# ...

# %%
import pandas as pd

# %%
from numpy import nan

# %%
#결측치 NAN을 0으로 바꾸기
df_0 = dataset.fillna(0)
df_0
# Out:
#             0                                1             2             3   \
# 0       Metric                 Market, Operator       Q1 2010       Q2 2010
# 1  Connections                 3 (CK Hutchison)    5,055,187     5,127,360
# 2  Connections                          EE (BT)   17,175,000    27,093,000
# 3  Connections                         Vodafone   19,954,383    19,965,191
# 4  Connections                  O2 (Telefónica)   21,355,500    21,605,600
# 5  Connections         Orange  (Merged Q2 2010)   16,442,000              0
# 6  Connections  Relish Broadband (UK Broadband)             0             0
# 7  Connections                   United Kingdom   79,982,070    73,791,151
#
#              4             5             6             7             8   \
# 0       Q3 2010       Q4 2010       Q1 2011       Q2 2011       Q3 2011
# 1    5,352,510     5,577,660     5,652,029     5,726,398     6,083,239
# 2   27,101,000    27,214,000    26,978,000    26,803,000    26,762,000
# ...

# %%
df_0[[0]['Q4 2018']]
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <ipython-input-13-a26ac4027f91>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   df_0[[0]['Q4 2018']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a26ac4027f91> in <module>
# ----> 1 df_0[[0]['Q4 2018']]
#
# TypeError: list indices must be integers or slices, not str
